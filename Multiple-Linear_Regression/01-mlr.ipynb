# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Load the dataset
dataset = pd.read_csv("/home/primes/Documents/COOPERATIVE UNIVERSITY OF KENYA/4.1/MACHINE-LEARNING/advertising.csv")

# Display the first few rows of the dataset
print(dataset.head())

# Summarize the dataset
print(dataset.describe())

# Define the features (independent variables) and target (dependent variable)
X = dataset[['TV', 'Radio', 'Newspaper']]
y = dataset['Sales']

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

# Initialize and train the multiple linear regression model
mlr = LinearRegression()
mlr.fit(X_train, y_train)

# Display the intercept and coefficients
print(f'Intercept: {mlr.intercept_}')
print(f'Coefficients: {list(zip(X.columns, mlr.coef_))}')

# Predict on test and training sets
y_pred_test = mlr.predict(X_test)
y_pred_train = mlr.predict(X_train)

# Compare actual and predicted values
mlr_diff = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_test})
print(mlr_diff.head())

# Visualize the actual vs. predicted values
plt.figure(figsize=(10, 5))
plt.scatter(range(len(y_test)), y_test, color="blue", label="Actual Sales")
plt.scatter(range(len(y_pred_test)), y_pred_test, color="red", label="Predicted Sales", marker='x')
plt.title("Actual vs Predicted Sales")
plt.xlabel("Data Points")
plt.ylabel("Sales")
plt.legend()
plt.show()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000
# Intercept: 4.41917662896895
# Coefficients: [('TV', np.float64(0.0537366242370921)), ('Radio', np.float64(0.106141598868424)), ('Newspaper', np.float64(0.005421568277052244))]
#      Actual  Predicted
# 126     6.6   9.241562
# 104    20.7  20.888632
# 99     17.2  16.359323
# ...
